# %% [markdown]
# > 5C34Y25 loves Programming 🤍

# %% [markdown]
# ### Playground:

# %%
import string

T = string.Template('$name : $job')

O_1 = T.substitute({'name': 'Moyu', 'job': 'dev'})

print(T) # output object's memory address

print(O_1) # output 1

# OR

O_2 = T.substitute(name = 'John', job = 'singer')

print(O_2) # output 2
# Out:
# ...
# Moyu : dev
# John : singer

# %% [markdown]
# Old School Python

# %%
# Dictionary subsitution for string template

info = {'name': 'John', 'age': 40}

hi = """
Greetings...

Hi %(name)s!
Are you age %(age)s this year ?
"""

print(hi % info)  # have to add %()s
# Out:
#
# Greetings...
#
# Hi John!
# Are you age 40 this year ?

# %%
# Just like .format()

print("My name is %s and I am %s years old." % ("Moyu", 18))
# Out:
# My name is Moyu and I am 18 years old.

# %% [markdown]
# Modern Python

# %%
info = {"name": "Moyu", "age": 18, "school": "DHS"}

print(f"Hi {info['name']}! You are {info['age']} years old.")

print('\n')

print(f"Hello {info.get('nam', 'Backup_Name')}, welcome!") # .get()

print('\n')

for key in info:
    print(f"{key.capitalize()}: {info[key]}") # Loop and print all keys and values
# Out:
# Hi Moyu! You are 18 years old.
#
#
# Hello Backup_Name, welcome!
#
#
# Name: Moyu
# Age: 18
# School: DHS

# %% [markdown]
# # Strings:
#
# ![image.png](data:image/png;base64,...)

# %%
emptystr = ''
print(emptystr)
print('Love you 3000!')
print("Let's go")
print('how to print " ')

# 'abd'[0] = 'x' <--- strings are immutable
# Out:
# Love you 3000!
# Let's go
# how to print "

# %% [markdown]
# ### Escape sequences

# %%
S = 's\np\ta\x00m' # \x00 is 'null', it can be counted as 1 char

print(S)
# Out:
# s
# p	ams

# %% [markdown]
# ### Raw strings

# %%
S = r'\temp\spam' # No escape

print(S)
# Out:
# \temp\sp\vam

# %% [markdown]
# ### Operators
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Concatenation, Repetition, Iteration
# ![image.png](data:image/png;base64,...)

# %%
print('ada' + ' lovelace')
print('#' * 8)

for i in range(5):
    print('*' * i)
# Out:
# ada lovelace
# ########
#
# *
# **
# ***
# ****

# %% [markdown]
# ### Indexing and Slicing
# ![image.png](data:image/png;base64,...)

# %%
greet = 'Hello Tom'

print(greet[1:3]) # end at 2 not 3
print(greet[slice(1,3)])

print(greet[2::2]) # skip 2-1 = 1 item each time
print(greet[::-1]) # reversing items
x = 8
print(greet[x-1], greet[-3])
# Out:
# el
# el
# loTm
# moT olleH
# o T

# %% [markdown]
# ### Length of string, typecasting, iterating through string
# ![image.png](data:image/png;base64,...)

# %%
len('1 #cat?')

print(str(True))

for char in 'abc123':
    print(char)

x = True
x = str(x)
x, type(x)
# Out:
# True
# a
# b
# c
# 1
# 2
# 3

# %% [markdown]
# ### Methods
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
s = ' hello, i came to look for you '

print('"' + s.lower() + '"')
print('"' + s.upper() + '"')

print('"' + s.lstrip() + '"') # remove leading only
print('"' + s.rstrip() + '"') # remove trailing only
print('"' + s.strip() + '"') # leading and trailing whitespace removed.

print(s.split()) # works the same for 1 or more whitespaces

print(s.split(','))
# Out:
# " hello, i came to look for you "
# " HELLO, I CAME TO LOOK FOR YOU "
# "hello, i came to look for you "
# " hello, i came to look for you"
# "hello, i came to look for you"
# ['hello,', 'i', 'came', 'to', 'look', 'for', 'you']
# [' hello', ' i came to look for you ']

# %% [markdown]
# ### Find and Replace

# %%
s = 'Hey There!'

print(s.find('er'))

s_no_space = s.replace(" ", "") # remove all spaces

print(s_no_space)
# Out:
# 6
# HeyThere!

# %% [markdown]
# ### For loop and ' ' in ' '

# %%
Me = 'student'

for x in Me: print(x, end=' ')

'ude' in Me
# Out:
# s t u d e n t
# True

# %% [markdown]
# Endswith and .join( )

# %%
S = 'Spaming'

print(S.startswith('S'))
print(S.endswith('ng'))

print('-'.join(S)) # separate each letter with '-' sign

L = list(S)
print(L)

print(''.join(L)) # can also be used for joining back list to a string
# Out:
# True
# True
# S-p-a-m-i-n-g
# ['S', 'p', 'a', 'm', 'i', 'n', 'g']
# Spaming

# %% [markdown]
# Copy and modify the text string ```'aB1 !'``` for all methods to return ```True```.
# ```
# print('aB1 !'.isupper())
# print('aB1 !'.islower())
# print('aB1 !'.isalnum())
# print('aB1 !'.isalpha())
# ```

# %%
print('AB1 !'.isupper())
print('ab1 !'.islower())
print('1'.isalnum())
print('aB'.isalpha()) # letters only
# Out:
# True
# True
# True
# True

# %% [markdown]
# ### Convert immutable string to an object that support in-place changes

# %%
S = 'Spem'

L = list(S)

L[2] = 'a'

L.extend(['m','y']) # append is only for single str item

L += 'test' # this is even more mind-blowing: same as .extend | iterable append !

for char in 'test2': # explanation
    L.append(char)

L

# Mutable object list :)
# Out:
# ['S', 'p', 'a', 'm', 'm', 'y', 't', 'e', 's', 't', 't', 'e', 's', 't', '2']

# %% [markdown]
# ### Formatted Printing

# %%
salute, surname, prize = 'Mr', 'Lim', 100

print('Hello {} {}, you have won ${}.'.format(salute,surname,prize))
# Out:
# Hello Mr Lim, you have won $100.

# %% [markdown]
# ### f-string
#
# While ```str.format()``` can be used, we shall be using f strings which are simpler to use.
#
# ![image.png](data:image/png;base64,...)

# %%
salute, surname, prize = 'Mr', 'Lim', 100

print(f'Hello {salute} {surname}, you have won ${prize}.')
# Out:
# Hello Mr Lim, you have won $100.
# Hello Mr Lim, you have won $100.

# %% [markdown]
# ### Format Specifiers
# ```
# PI = 3.14159
# area = PI*5**2
# print(f'area of circle: "{area}" sq unit, unformatted')
# print(f'area of circle: "{area}" sq unit, width 9')
# print(f'area of circle: "{area}" sq unit, width 9, 3sf')
# print(f'area of circle: "{area:9.3f}" sq unit, width 9, 3dp') #completed example
# ```

# %%
PI = 3.14159
area = PI*5**2
print(f'area of circle: "{area}" sq unit, unformatted')
print(f'area of circle: "{area:8}" sq unit, width 8')
print(f'area of circle: "{area:4.3}" sq unit, width 8, 3sf')
print(f'area of circle: "{area:5.3f}" sq unit, width 8, 3dp')
# Out:
# area of circle: "78.53975" sq unit, unformatted
# area of circle: "78.53975" sq unit, width 9
# area of circle: "78.5" sq unit, width 9, 3sf
# area of circle: "78.540" sq unit, width 9, 3dp

# %% [markdown]
# ### Left, centre and right justification
# ![image.png](data:image/png;base64,...)

# %%
letter = 'a'

print(f'left justify\t:12345')
print(f'left justify\t:{letter:<5}')
print(f'right justify\t:{letter:>5}')
print(f'centre justify\t:{letter:^5}') # Between 1 and 5, is 3
# Out:
# left justify	:12345
# left justify	:a
# right justify	:    a
# centre justify	:  a

# %% [markdown]
# ```
# PI = 3.14159
# area = PI*5**2
# print(f'area of circle: "{area}" sq unit, centre justified, width 9, 3dp')
# ```

# %%
PI = 3.14159
area = PI*5**2
print(f'area of circle: "{area:^8.3f}" sq unit, centre justified, width 8, 3dp')
# Out:
# area of circle: " 78.540 " sq unit, centre justified, width 9, 3dp

# %% [markdown]
# ### Special Characters and Escape Sequences
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ```
# print('backslash: single quote: double quote:')
# ```
#
# ![image.png](data:image/png;base64,...)

# %%
print(" backslash\t:\\ \n single quote\t:\' \n double quote\t:\"  ")
# Out:
#  backslash	:\
#  single quote	:'
#  double quote	:"

# %% [markdown]
# ### Multi-line strings
# - Break up this if statement with backslash ```\``` to improve readability:
# ```
# a_very_long_variable_name = True
# b_very_long_variable_name = True
# while True:
#     if a_very_long_variable_name == b_very_long_variable_name and a_very_long_variable_name or b_very_long_variable_name and a_very_long_variable_name or b_very_long_variable_name:
#         print('the logical expression above simplifies to True')
#     break
# ```

# %%
a_very_long_variable_name = True
b_very_long_variable_name = True

while True: # if a == b and a or b and a or b:

    if a_very_long_variable_name == b_very_long_variable_name and \
    a_very_long_variable_name or b_very_long_variable_name and \
    a_very_long_variable_name or b_very_long_variable_name: # (((a == b) and a) or ((b and a)) or b)


        print('the logical expression above simplifies to True') # ((True and True) or (True and True) or True)

    break
# Out:
# the logical expression above simplifies to True

# %% [markdown]
# ### ```print``` function
#
# ![image.png](data:image/png;base64,...)

# %%
for i in range(5):
    print(i, i+1, i+2, sep = ',', end = '|')
# Out:
# 0,1,2|1,2,3|2,3,4|3,4,5|4,5,6|

# %% [markdown]
# ### Writing and reading comments and Document strings
# > Comments and document strings (or docstrings) are programmer remarks and pertinent info meant for fellow programmers and users, and even oneself to read. They can also be used for debugging faulty code. Although docstrings main feature is in support of code documentation, it is particularly useful in helping to test code in chunks.
#
# > Add one or more ```#``` to the start of a phrase to make it a comment:
#
# ```
# ####################
# #even index number#
# ####################
# for i in range(1,29):   #loop for every student index number 1 to 28
#     if i%2 == 0:        #checks if index is even number
#         print(f'{i} is even index number')
# ```
# > Docstrings are wrapped with triple inverted commas like this:
# ```'''this is a document string'''```
#
# >Docstrings can be accessed via the ```help()``` function. THIS CAN BE USEFUL IN A PRACTICAL EXAM, and checking instructions on how to use a function is allowed during the exam.
# >Try accessing docstrings using ```help(print)``` for built-in functions or ```help(str.strip)``` for class based methods.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help(str.strip)
# Out:
# Help on method_descriptor:
#
# strip(self, chars=None, /) unbound builtins.str method
#     Return a copy of the string with leading and trailing whitespace removed.
#
#     If chars is given and not None, remove characters in chars instead.

# %%
def testfunction():

    '''
    This is the function documentation
    '''
    pass

# %%
help(testfunction)
# Out:
# Help on function testfunction in module __main__:
#
# testfunction()
#     This is the function documentation

# %% [markdown]
# > Copy this description and insert as a docstring in the function named ```divide(x,y)```. Subsequently, use the ```help()``` function to display the docstring you have written.
# ```
#     Name of programmer: Mr Fong Kwok Kwong
#     Date written/updated: 02/01/2024
#     Program: Division Version 1.0.0
#     Purpose: to calculate the division of dividend by divisor
#     input/arguments- x: integer dividend, y: integer divisor
#     output: returns a float
# ```

# %%
def divide(x,y):

    '''
    Name of programmer: Moyu
    Date written/updated: 03/04/2025
    Program: Division Version 1.0.0
    Purpose: to calculate the division of dividend by divisor
    input/arguments- x: integer dividend, y: integer divisor
    output: returns a float
    '''

    return x/y

print(divide(6,3))
# Out:
# 2.0

# %%
help(divide)
# Out:
# Help on function divide in module __main__:
#
# divide(x, y)
#     Name of programmer: Moyu
#     Date written/updated: 03/04/2025
#     Program: Division Version 1.0.0
#     Purpose: to calculate the division of dividend by divisor
#     input/arguments- x: integer dividend, y: integer divisor
#     output: returns a float

# %% [markdown]
# ### Programming Project Related Questions
#
# > Example 4
#
# > Translate the pseudocode for validation of ```subjectcode``` below to python code, adding an input line and an output line for ```validFlag``` at the start and end of the program respectively.
#
# > ```subjectcode``` is used to uniquely identify a particular subject and is four digits. A valid ```subjectcode``` is 4 characters long and contain only digits.
#
# ![image.png](data:image/png;base64,...)

# %%
def validate_subject_code():

    subjectCode = input("Enter the subject code: ")

    validFlag = True

    if len(subjectCode) != 4:
        print("Error! Subject Code must be 4 digits.")
        validFlag = False

    elif not subjectCode.isdigit():
        print("Error! Subject Code contains only digits only.")
        validFlag = False

    print("validFlag =", validFlag)

validate_subject_code()
# Out:
# Enter the subject code: 9999
# validFlag = True
